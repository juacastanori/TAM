# %%
# !pip install gym-super-mario-bros==7.4.0 nes-py pyvirtualdisplay
# !apt-get update && apt-get install -y xvfb ffmpeg
# Out:
# Collecting gym-super-mario-bros==7.4.0
#   Downloading gym_super_mario_bros-7.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting nes-py
#   Downloading nes_py-8.2.1.tar.gz (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.7/77.7 kB 2.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl.metadata (943 bytes)
# Requirement already satisfied: gym>=0.17.2 in /usr/local/lib/python3.11/dist-packages (from nes-py) (0.25.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.11/dist-packages (from nes-py) (1.26.4)
# Collecting pyglet<=1.5.21,>=1.4.0 (from nes-py)
#   Downloading pyglet-1.5.21-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: tqdm>=4.48.2 in /usr/local/lib/python3.11/dist-packages (from nes-py) (4.67.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gym>=0.17.2->nes-py) (3.1.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.11/dist-packages (from gym>=0.17.2->nes-py) (0.0.8)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.5->nes-py) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.5->nes-py) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.5->nes-py) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.5->nes-py) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.5->nes-py) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.5->nes-py) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.18.5->nes-py) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.18.5->nes-py) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.18.5->nes-py) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.18.5->nes-py) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.18.5->nes-py) (2024.2.0)
# Downloading gym_super_mario_bros-7.4.0-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 kB 10.8 MB/s eta 0:00:00
# Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Downloading pyglet-1.5.21-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 36.8 MB/s eta 0:00:00
# Building wheels for collected packages: nes-py
#   Building wheel for nes-py (setup.py) ... done
#   Created wheel for nes-py: filename=nes_py-8.2.1-cp311-cp311-linux_x86_64.whl size=535717 sha256=62f137fc446b3510771ab00e0cc80e44650fff17b6fa1e37bc4c60085b45629f
#   Stored in directory: /root/.cache/pip/wheels/be/b4/5a/68b9155f1d2380af0e359c71efd4c70518555be4c2f577f1d3
# Successfully built nes-py
# Installing collected packages: pyvirtualdisplay, pyglet, nes-py, gym-super-mario-bros
# Successfully installed gym-super-mario-bros-7.4.0 nes-py-8.2.1 pyglet-1.5.21 pyvirtualdisplay-3.0
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [79.8 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,804 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,751 kB]
# Get:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,566 kB]
# Get:13 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [4,917 kB]
# Get:15 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,078 kB]
# Get:16 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease [24.6 kB]
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,092 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [56.4 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,404 kB]
# Get:20 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [33.2 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [35.2 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [83.2 kB]
# Get:23 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy/main amd64 Packages [51.0 kB]
# Get:24 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 Packages [75.1 kB]
# Get:25 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [48.5 kB]
# Get:26 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,262 kB]
# Get:27 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [4,763 kB]
# Fetched 33.6 MB in 3s (12.5 MB/s)
#
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
#
#
#
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# The following packages will be upgraded:
#   xserver-common xvfb
# 2 upgraded, 0 newly installed, 0 to remove and 198 not upgraded.
# Need to get 896 kB of archives.
# After this operation, 0 B of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-common all 2:21.1.4-2ubuntu1.7~22.04.15 [29.5 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 xvfb amd64 2:21.1.4-2ubuntu1.7~22.04.15 [866 kB]
# Fetched 896 kB in 1s (725 kB/s)
# (Reading database ... 129184 files and directories currently installed.)
# Preparing to unpack .../xserver-common_2%3a21.1.4-2ubuntu1.7~22.04.15_all.deb ...
# Unpacking xserver-common (2:21.1.4-2ubuntu1.7~22.04.15) over (2:21.1.4-2ubuntu1.7~22.04.14) ...
# Preparing to unpack .../xvfb_2%3a21.1.4-2ubuntu1.7~22.04.15_amd64.deb ...
# Unpacking xvfb (2:21.1.4-2ubuntu1.7~22.04.15) over (2:21.1.4-2ubuntu1.7~22.04.14) ...
# Setting up xserver-common (2:21.1.4-2ubuntu1.7~22.04.15) ...
# Setting up xvfb (2:21.1.4-2ubuntu1.7~22.04.15) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
import random
import numpy as np
import cv2
import gym
import gym_super_mario_bros
from nes_py.wrappers import JoypadSpace
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT
from collections import deque
from pyvirtualdisplay import Display

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# Configurar dispositivo (GPU si está disponible)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Usando dispositivo:", device)

# Inicializar un display virtual para render (necesario para guardar video)
display = Display(visible=0, size=(1400, 900))
display.start()
# Out:
# Usando dispositivo: cuda

# %%
# Crear entorno (puede ser "SuperMarioBros-v0" o un nivel específico como "SuperMarioBros-1-1-v0")
env = gym_super_mario_bros.make("SuperMarioBros-v0")
env = JoypadSpace(env, SIMPLE_MOVEMENT)
n_actions = env.action_space.n
print("Número de acciones:", n_actions)
# Out:
# /usr/local/lib/python3.11/dist-packages/gym/envs/registration.py:593: UserWarning: WARN: The environment SuperMarioBros-v0 is out of date. You should consider upgrading to version `v3`.
#   logger.warn(
# Número de acciones: 7
# /usr/local/lib/python3.11/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.11/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(

# %%
def preprocess_frame(frame):
    """Convierte un fotograma RGB a escala de grises 84x84."""
    gray = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
    resized = cv2.resize(gray, (84, 84), interpolation=cv2.INTER_AREA)
    normalized = resized.astype(np.float32) / 255.0
    return normalized  # matriz 84x84

# Ejemplo: obtener el primer estado (apilando 4 veces el fotograma inicial)
obs = env.reset()
state = preprocess_frame(obs)
state_stack = np.stack([state] * 4, axis=0)  # shape = (4, 84, 84)

# %%
class DQN(nn.Module):
    def __init__(self, input_channels, num_actions):
        super(DQN, self).__init__()
        # Capas convolucionales
        self.conv1 = nn.Conv2d(input_channels, 32, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
        # Capa totalmente conectada
        self.fc_input_dim = self._get_conv_output((input_channels, 84, 84))
        self.fc1 = nn.Linear(self.fc_input_dim, 512)
        self.fc2 = nn.Linear(512, num_actions)
    
    def _get_conv_output(self, shape):
        # Función auxiliar para calcular tamaño de salida del bloque conv
        o = torch.zeros(1, *shape)
        o = self.conv1(o)
        o = self.conv2(o)
        o = self.conv3(o)
        return int(np.prod(o.size()))
    
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        return self.fc2(x)

# Crear redes en línea (policy_net) y target (target_net)
policy_net = DQN(input_channels=4, num_actions=n_actions).to(device)
target_net = DQN(input_channels=4, num_actions=n_actions).to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()  # Red target en modo evaluación
# Out:
# DQN(
#   (conv1): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#   (conv2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=3136, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=7, bias=True)
# )

# %%
class ReplayBuffer:
    def __init__(self, capacity):
        self.capacity = capacity
        self.buffer = deque(maxlen=capacity)
    
    def push(self, state, action, reward, next_state, done):
        # Se clonan arrays para evitar referencias mutables
        state = np.array(state, copy=False)
        next_state = np.array(next_state, copy=False)
        self.buffer.append((state, action, reward, next_state, done))
    
    def sample(self, batch_size):
        # Muestra al azar un batch de transiciones
        transitions = random.sample(self.buffer, batch_size)
        states, actions, rewards, next_states, dones = zip(*transitions)
        return np.array(states), actions, rewards, np.array(next_states), dones
    
    def __len__(self):
        return len(self.buffer)

# Inicializar memoria
memory = ReplayBuffer(capacity=200000)

# %%
# Hiperparámetros
num_episodes = 800            # número de episodios de entrenamiento
max_steps_per_episode = 5000   # tope de pasos por episodio
batch_size = 32
gamma = 0.99                   # factor de descuento
learning_rate = 1e-4
epsilon_start = 1.0
epsilon_end = 0.1
epsilon_decay = 200000         # pasos para decaer ε
target_update = 10             # episodios para actualizar target_net

optimizer = optim.Adam(policy_net.parameters(), lr=learning_rate)

steps_done = 0
epsilon = epsilon_start

for episode in range(num_episodes):
    obs = env.reset()
    state = preprocess_frame(obs)
    state_stack = np.stack([state]*4, axis=0)  # inicializar stack de 4 frames
    total_reward = 0
    
    for t in range(max_steps_per_episode):
        # ε-greedy: decidir acción
        if random.random() < epsilon:
            action = random.randrange(n_actions)
        else:
            with torch.no_grad():
                state_tensor = torch.tensor(state_stack, dtype=torch.float32, device=device).unsqueeze(0)
                q_values = policy_net(state_tensor)
                action = q_values.argmax().item()
        
        # Ejecutar acción en el entorno
        next_obs, reward, done, info = env.step(action)
        next_frame = preprocess_frame(next_obs)
        next_state_stack = np.concatenate([state_stack[1:], next_frame[np.newaxis, ...]], axis=0)
        
        # Almacenar transición en memoria
        memory.push(state_stack, action, reward, next_state_stack, done)
        total_reward += reward
        state_stack = next_state_stack
        
        # Actualizar ε
        steps_done += 1
        epsilon = max(epsilon_end, epsilon_start - steps_done / epsilon_decay)
        
        # Realizar optimización si hay muestras suficientes
        if len(memory) >= batch_size:
            states, actions, rewards, next_states, dones = memory.sample(batch_size)
            
            # Convertir a tensores
            states_v = torch.tensor(states, dtype=torch.float32, device=device)
            next_states_v = torch.tensor(next_states, dtype=torch.float32, device=device)
            actions_v = torch.tensor(actions, dtype=torch.int64, device=device).unsqueeze(1)
            rewards_v = torch.tensor(rewards, dtype=torch.float32, device=device)
            dones_v = torch.tensor(dones, dtype=torch.float32, device=device)
            
            # Calcular Q(s,a) con red online
            q_values = policy_net(states_v).gather(1, actions_v).squeeze(1)
            # Seleccionar acciones con red online para siguiente estado (Double DQN)
            next_actions = policy_net(next_states_v).argmax(dim=1, keepdim=True)
            # Calcular Q target con red target
            next_q_values = target_net(next_states_v).gather(1, next_actions).squeeze(1)
            expected_q_values = rewards_v + gamma * next_q_values * (1 - dones_v)
            
            # Pérdida Huber (Smooth L1) para estabilidad
            loss = F.smooth_l1_loss(q_values, expected_q_values.detach())
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        
        if done:
            break
    
    # Actualizar red target cada ciertos episodios
    if episode % target_update == 0:
        target_net.load_state_dict(policy_net.state_dict())
    
    print(f"Episodio {episode+1}/{num_episodes} - Recompensa: {total_reward:.1f} - ε={epsilon:.3f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/gym/utils/passive_env_checker.py:227: DeprecationWarning: WARN: Core environment is written in old step API which returns one bool instead of two. It is recommended to rewrite the environment with new step API.
#   logger.deprecation(
# /usr/local/lib/python3.11/dist-packages/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(done, (bool, np.bool8)):
# Episodio 1/800 - Recompensa: 544.0 - ε=0.975
# Episodio 2/800 - Recompensa: 303.0 - ε=0.950
# Episodio 3/800 - Recompensa: 304.0 - ε=0.925
# Episodio 4/800 - Recompensa: 799.0 - ε=0.900
# Episodio 5/800 - Recompensa: 304.0 - ε=0.875
# Episodio 6/800 - Recompensa: 303.0 - ε=0.850
# Episodio 7/800 - Recompensa: 432.0 - ε=0.825
# Episodio 8/800 - Recompensa: 304.0 - ε=0.800
# Episodio 9/800 - Recompensa: 432.0 - ε=0.775
# Episodio 10/800 - Recompensa: 839.0 - ε=0.750
# Episodio 11/800 - Recompensa: 429.0 - ε=0.725
# Episodio 12/800 - Recompensa: 1056.0 - ε=0.700
# Episodio 13/800 - Recompensa: 304.0 - ε=0.675
# Episodio 14/800 - Recompensa: 553.0 - ε=0.650
# Episodio 15/800 - Recompensa: 963.0 - ε=0.625
# Episodio 16/800 - Recompensa: 972.0 - ε=0.600
# Episodio 17/800 - Recompensa: 304.0 - ε=0.575
# Episodio 18/800 - Recompensa: 979.0 - ε=0.560
# Episodio 19/800 - Recompensa: 432.0 - ε=0.535
# Episodio 20/800 - Recompensa: 808.0 - ε=0.510
# Episodio 21/800 - Recompensa: 1602.0 - ε=0.485
# Episodio 22/800 - Recompensa: 1941.0 - ε=0.460
# Episodio 23/800 - Recompensa: 1388.0 - ε=0.446
# Episodio 24/800 - Recompensa: 1276.0 - ε=0.421
# Episodio 25/800 - Recompensa: 680.0 - ε=0.396
# Episodio 26/800 - Recompensa: 1293.0 - ε=0.371
# Episodio 27/800 - Recompensa: 1116.0 - ε=0.360
# Episodio 28/800 - Recompensa: 1119.0 - ε=0.339
# Episodio 29/800 - Recompensa: 685.0 - ε=0.314
# Episodio 30/800 - Recompensa: 608.0 - ε=0.289
# Episodio 31/800 - Recompensa: 1230.0 - ε=0.264
# Episodio 32/800 - Recompensa: 1384.0 - ε=0.252
# Episodio 33/800 - Recompensa: 1352.0 - ε=0.227
# Episodio 34/800 - Recompensa: 1412.0 - ε=0.214
# Episodio 35/800 - Recompensa: 856.0 - ε=0.189
# Episodio 36/800 - Recompensa: 1623.0 - ε=0.181
# Episodio 37/800 - Recompensa: 1794.0 - ε=0.156
# Episodio 38/800 - Recompensa: 1983.0 - ε=0.138
# Episodio 39/800 - Recompensa: 2055.0 - ε=0.128
# Episodio 40/800 - Recompensa: 1664.0 - ε=0.123
# Episodio 41/800 - Recompensa: 2196.0 - ε=0.116
# Episodio 42/800 - Recompensa: 3084.0 - ε=0.100
# Episodio 43/800 - Recompensa: 1814.0 - ε=0.100
# Episodio 44/800 - Recompensa: 1104.0 - ε=0.100
# Episodio 45/800 - Recompensa: 2494.0 - ε=0.100
# Episodio 46/800 - Recompensa: 3190.0 - ε=0.100
# Episodio 47/800 - Recompensa: 1497.0 - ε=0.100
# Episodio 48/800 - Recompensa: 2250.0 - ε=0.100
# Episodio 49/800 - Recompensa: 1847.0 - ε=0.100
# Episodio 50/800 - Recompensa: 1701.0 - ε=0.100
# Episodio 51/800 - Recompensa: 1664.0 - ε=0.100
# Episodio 52/800 - Recompensa: 1495.0 - ε=0.100
# Episodio 53/800 - Recompensa: 2484.0 - ε=0.100
# Episodio 54/800 - Recompensa: 1996.0 - ε=0.100
# Episodio 55/800 - Recompensa: 2948.0 - ε=0.100
# Episodio 56/800 - Recompensa: 2293.0 - ε=0.100
# Episodio 57/800 - Recompensa: 1415.0 - ε=0.100
# Episodio 58/800 - Recompensa: 1337.0 - ε=0.100
# Episodio 59/800 - Recompensa: 1416.0 - ε=0.100
# Episodio 60/800 - Recompensa: 1207.0 - ε=0.100
# Episodio 61/800 - Recompensa: 2713.0 - ε=0.100
# Episodio 62/800 - Recompensa: 2158.0 - ε=0.100
# Episodio 63/800 - Recompensa: 1461.0 - ε=0.100
# Episodio 64/800 - Recompensa: 1204.0 - ε=0.100
# Episodio 65/800 - Recompensa: 2025.0 - ε=0.100
# Episodio 66/800 - Recompensa: 1505.0 - ε=0.100
# Episodio 67/800 - Recompensa: 1208.0 - ε=0.100
# Episodio 68/800 - Recompensa: 1642.0 - ε=0.100
# Episodio 69/800 - Recompensa: 1699.0 - ε=0.100
# Episodio 70/800 - Recompensa: 1506.0 - ε=0.100
# Episodio 71/800 - Recompensa: 1467.0 - ε=0.100
# Episodio 72/800 - Recompensa: 865.0 - ε=0.100
# Episodio 73/800 - Recompensa: 2220.0 - ε=0.100
# Episodio 74/800 - Recompensa: 2414.0 - ε=0.100
# Episodio 75/800 - Recompensa: 3220.0 - ε=0.100
# Episodio 76/800 - Recompensa: 1078.0 - ε=0.100
# Episodio 77/800 - Recompensa: 1930.0 - ε=0.100
# Episodio 78/800 - Recompensa: 1500.0 - ε=0.100
# Episodio 79/800 - Recompensa: 1623.0 - ε=0.100
# Episodio 80/800 - Recompensa: 2564.0 - ε=0.100
# Episodio 81/800 - Recompensa: 1498.0 - ε=0.100
# Episodio 82/800 - Recompensa: 1612.0 - ε=0.100
# Episodio 83/800 - Recompensa: 1993.0 - ε=0.100
# Episodio 84/800 - Recompensa: 1279.0 - ε=0.100
# Episodio 85/800 - Recompensa: 2400.0 - ε=0.100
# Episodio 86/800 - Recompensa: 2286.0 - ε=0.100
# Episodio 87/800 - Recompensa: 1826.0 - ε=0.100
# Episodio 88/800 - Recompensa: 725.0 - ε=0.100
# Episodio 89/800 - Recompensa: 1277.0 - ε=0.100
# Episodio 90/800 - Recompensa: 1842.0 - ε=0.100
# Episodio 91/800 - Recompensa: 2015.0 - ε=0.100
# Episodio 92/800 - Recompensa: 1952.0 - ε=0.100
# Episodio 93/800 - Recompensa: 2655.0 - ε=0.100
# Episodio 94/800 - Recompensa: 1851.0 - ε=0.100
# Episodio 95/800 - Recompensa: 2476.0 - ε=0.100
# Episodio 96/800 - Recompensa: 1798.0 - ε=0.100
# Episodio 97/800 - Recompensa: 1208.0 - ε=0.100
# Episodio 98/800 - Recompensa: 3312.0 - ε=0.100
# Episodio 99/800 - Recompensa: 608.0 - ε=0.100
# Episodio 100/800 - Recompensa: 1451.0 - ε=0.100
# Episodio 101/800 - Recompensa: 1949.0 - ε=0.100
# Episodio 102/800 - Recompensa: 2257.0 - ε=0.100
# Episodio 103/800 - Recompensa: 1424.0 - ε=0.100
# Episodio 104/800 - Recompensa: 1689.0 - ε=0.100
# Episodio 105/800 - Recompensa: 1795.0 - ε=0.100
# Episodio 106/800 - Recompensa: 2374.0 - ε=0.100
# Episodio 107/800 - Recompensa: 1504.0 - ε=0.100
# Episodio 108/800 - Recompensa: 2142.0 - ε=0.100
# Episodio 109/800 - Recompensa: 1115.0 - ε=0.100
# Episodio 110/800 - Recompensa: 1408.0 - ε=0.100
# Episodio 111/800 - Recompensa: 1817.0 - ε=0.100
# Episodio 112/800 - Recompensa: 1082.0 - ε=0.100
# Episodio 113/800 - Recompensa: 1999.0 - ε=0.100
# Episodio 114/800 - Recompensa: 1853.0 - ε=0.100
# Episodio 115/800 - Recompensa: 2892.0 - ε=0.100
# Episodio 116/800 - Recompensa: 2054.0 - ε=0.100
# Episodio 117/800 - Recompensa: 1071.0 - ε=0.100
# Episodio 118/800 - Recompensa: 1956.0 - ε=0.100
# Episodio 119/800 - Recompensa: 2906.0 - ε=0.100
# Episodio 120/800 - Recompensa: 1965.0 - ε=0.100
# Episodio 121/800 - Recompensa: 1636.0 - ε=0.100
# Episodio 122/800 - Recompensa: 1752.0 - ε=0.100
# Episodio 123/800 - Recompensa: 1828.0 - ε=0.100
# Episodio 124/800 - Recompensa: 2250.0 - ε=0.100
# Episodio 125/800 - Recompensa: 432.0 - ε=0.100
# Episodio 126/800 - Recompensa: 1950.0 - ε=0.100
# Episodio 127/800 - Recompensa: 1343.0 - ε=0.100
# Episodio 128/800 - Recompensa: 1903.0 - ε=0.100
# Episodio 129/800 - Recompensa: 2001.0 - ε=0.100
# Episodio 130/800 - Recompensa: 1100.0 - ε=0.100
# Episodio 131/800 - Recompensa: 1413.0 - ε=0.100
# Episodio 132/800 - Recompensa: 1758.0 - ε=0.100
# Episodio 133/800 - Recompensa: 602.0 - ε=0.100
# Episodio 134/800 - Recompensa: 708.0 - ε=0.100
# Episodio 135/800 - Recompensa: 1437.0 - ε=0.100
# Episodio 136/800 - Recompensa: 2214.0 - ε=0.100
# Episodio 137/800 - Recompensa: 2552.0 - ε=0.100
# Episodio 138/800 - Recompensa: 432.0 - ε=0.100
# Episodio 139/800 - Recompensa: 1870.0 - ε=0.100
# Episodio 140/800 - Recompensa: 2969.0 - ε=0.100
# Episodio 141/800 - Recompensa: 1331.0 - ε=0.100
# Episodio 142/800 - Recompensa: 1932.0 - ε=0.100
# Episodio 143/800 - Recompensa: 2596.0 - ε=0.100
# Episodio 144/800 - Recompensa: 432.0 - ε=0.100
# Episodio 145/800 - Recompensa: 1084.0 - ε=0.100
# Episodio 146/800 - Recompensa: 3209.0 - ε=0.100
# Episodio 147/800 - Recompensa: 1236.0 - ε=0.100
# Episodio 148/800 - Recompensa: 1679.0 - ε=0.100
# Episodio 149/800 - Recompensa: 1902.0 - ε=0.100
# Episodio 150/800 - Recompensa: 2245.0 - ε=0.100
# Episodio 151/800 - Recompensa: 1073.0 - ε=0.100
# Episodio 152/800 - Recompensa: 1614.0 - ε=0.100
# Episodio 153/800 - Recompensa: 2118.0 - ε=0.100
# Episodio 154/800 - Recompensa: 2113.0 - ε=0.100
# Episodio 155/800 - Recompensa: 1729.0 - ε=0.100
# Episodio 156/800 - Recompensa: 2006.0 - ε=0.100
# Episodio 157/800 - Recompensa: 1759.0 - ε=0.100
# Episodio 158/800 - Recompensa: 1991.0 - ε=0.100
# Episodio 159/800 - Recompensa: 1552.0 - ε=0.100
# Episodio 160/800 - Recompensa: 1788.0 - ε=0.100
# Episodio 161/800 - Recompensa: 2481.0 - ε=0.100
# Episodio 162/800 - Recompensa: 1276.0 - ε=0.100
# Episodio 163/800 - Recompensa: 1417.0 - ε=0.100
# Episodio 164/800 - Recompensa: 2505.0 - ε=0.100
# Episodio 165/800 - Recompensa: 1083.0 - ε=0.100
# Episodio 166/800 - Recompensa: 2403.0 - ε=0.100
# Episodio 167/800 - Recompensa: 608.0 - ε=0.100
# Episodio 168/800 - Recompensa: 1493.0 - ε=0.100
# Episodio 169/800 - Recompensa: 2721.0 - ε=0.100
# Episodio 170/800 - Recompensa: 1737.0 - ε=0.100
# Episodio 171/800 - Recompensa: 1663.0 - ε=0.100
# Episodio 172/800 - Recompensa: 1847.0 - ε=0.100
# Episodio 173/800 - Recompensa: 2674.0 - ε=0.100
# Episodio 174/800 - Recompensa: 1566.0 - ε=0.100
# Episodio 175/800 - Recompensa: 1815.0 - ε=0.100
# Episodio 176/800 - Recompensa: 2559.0 - ε=0.100
# Episodio 177/800 - Recompensa: 2034.0 - ε=0.100
# Episodio 178/800 - Recompensa: 2362.0 - ε=0.100
# Episodio 179/800 - Recompensa: 1555.0 - ε=0.100
# Episodio 180/800 - Recompensa: 1626.0 - ε=0.100
# Episodio 181/800 - Recompensa: 2439.0 - ε=0.100
# Episodio 182/800 - Recompensa: 2860.0 - ε=0.100
# Episodio 183/800 - Recompensa: 1507.0 - ε=0.100
# Episodio 184/800 - Recompensa: 1357.0 - ε=0.100
# Episodio 540/800 - Recompensa: 2571.0 - ε=0.100
# Episodio 541/800 - Recompensa: 1986.0 - ε=0.100
# Episodio 542/800 - Recompensa: 1686.0 - ε=0.100
# Episodio 543/800 - Recompensa: 2255.0 - ε=0.100
# Episodio 544/800 - Recompensa: 2361.0 - ε=0.100
# Episodio 545/800 - Recompensa: 1984.0 - ε=0.100
# Episodio 546/800 - Recompensa: 2143.0 - ε=0.100
# Episodio 547/800 - Recompensa: 2072.0 - ε=0.100
# Episodio 548/800 - Recompensa: 1261.0 - ε=0.100
# Episodio 549/800 - Recompensa: 2338.0 - ε=0.100
# Episodio 550/800 - Recompensa: 3427.0 - ε=0.100
# Episodio 551/800 - Recompensa: 1928.0 - ε=0.100
# Episodio 552/800 - Recompensa: 1740.0 - ε=0.100
# Episodio 553/800 - Recompensa: 2648.0 - ε=0.100
# Episodio 554/800 - Recompensa: 1797.0 - ε=0.100
# Episodio 555/800 - Recompensa: 3105.0 - ε=0.100
# Episodio 556/800 - Recompensa: 2286.0 - ε=0.100
# Episodio 557/800 - Recompensa: 1413.0 - ε=0.100
# Episodio 558/800 - Recompensa: 1811.0 - ε=0.100
# Episodio 559/800 - Recompensa: 1524.0 - ε=0.100
# Episodio 560/800 - Recompensa: 2421.0 - ε=0.100
# Episodio 561/800 - Recompensa: 1490.0 - ε=0.100
# Episodio 562/800 - Recompensa: 2012.0 - ε=0.100
# Episodio 563/800 - Recompensa: 1108.0 - ε=0.100
# Episodio 564/800 - Recompensa: 2115.0 - ε=0.100
# Episodio 565/800 - Recompensa: 1716.0 - ε=0.100
# Episodio 566/800 - Recompensa: 2983.0 - ε=0.100
# Episodio 567/800 - Recompensa: 1759.0 - ε=0.100
# Episodio 568/800 - Recompensa: 2415.0 - ε=0.100
# Episodio 569/800 - Recompensa: 1606.0 - ε=0.100
# Episodio 570/800 - Recompensa: 498.0 - ε=0.100
# Episodio 571/800 - Recompensa: 1563.0 - ε=0.100
# Episodio 572/800 - Recompensa: 1342.0 - ε=0.100
# Episodio 573/800 - Recompensa: 1804.0 - ε=0.100
# Episodio 574/800 - Recompensa: 2536.0 - ε=0.100
# Episodio 575/800 - Recompensa: 2230.0 - ε=0.100
# Episodio 576/800 - Recompensa: 2492.0 - ε=0.100
# Episodio 577/800 - Recompensa: 1909.0 - ε=0.100
# Episodio 578/800 - Recompensa: 1481.0 - ε=0.100
# Episodio 579/800 - Recompensa: 2166.0 - ε=0.100
# Episodio 580/800 - Recompensa: 1757.0 - ε=0.100
# Episodio 581/800 - Recompensa: 1760.0 - ε=0.100
# Episodio 582/800 - Recompensa: 1554.0 - ε=0.100
# Episodio 583/800 - Recompensa: 1865.0 - ε=0.100
# Episodio 584/800 - Recompensa: 1863.0 - ε=0.100
# Episodio 585/800 - Recompensa: 2739.0 - ε=0.100
# Episodio 586/800 - Recompensa: 1803.0 - ε=0.100
# Episodio 587/800 - Recompensa: 2064.0 - ε=0.100
# Episodio 588/800 - Recompensa: 1178.0 - ε=0.100
# Episodio 589/800 - Recompensa: 2929.0 - ε=0.100
# Episodio 590/800 - Recompensa: 2117.0 - ε=0.100
# Episodio 591/800 - Recompensa: 1209.0 - ε=0.100
# Episodio 592/800 - Recompensa: 1687.0 - ε=0.100
# Episodio 593/800 - Recompensa: 2709.0 - ε=0.100
# Episodio 594/800 - Recompensa: 3080.0 - ε=0.100
# Episodio 595/800 - Recompensa: 1449.0 - ε=0.100
# Episodio 596/800 - Recompensa: 2354.0 - ε=0.100
# Episodio 597/800 - Recompensa: 2558.0 - ε=0.100
# Episodio 598/800 - Recompensa: 1602.0 - ε=0.100
# Episodio 599/800 - Recompensa: 2106.0 - ε=0.100
# Episodio 600/800 - Recompensa: 2327.0 - ε=0.100
# Episodio 601/800 - Recompensa: 2196.0 - ε=0.100
# Episodio 602/800 - Recompensa: 1984.0 - ε=0.100
# Episodio 603/800 - Recompensa: 1591.0 - ε=0.100
# Episodio 604/800 - Recompensa: 1601.0 - ε=0.100
# Episodio 605/800 - Recompensa: 1877.0 - ε=0.100
# Episodio 606/800 - Recompensa: 2000.0 - ε=0.100
# Episodio 607/800 - Recompensa: 1112.0 - ε=0.100
# Episodio 608/800 - Recompensa: 1076.0 - ε=0.100
# Episodio 609/800 - Recompensa: 2299.0 - ε=0.100
# Episodio 610/800 - Recompensa: 1825.0 - ε=0.100
# Episodio 611/800 - Recompensa: 679.0 - ε=0.100
# Episodio 612/800 - Recompensa: 1452.0 - ε=0.100
# Episodio 613/800 - Recompensa: 2114.0 - ε=0.100
# Episodio 614/800 - Recompensa: 2336.0 - ε=0.100
# Episodio 615/800 - Recompensa: 1983.0 - ε=0.100
# Episodio 616/800 - Recompensa: 2088.0 - ε=0.100
# Episodio 617/800 - Recompensa: 1337.0 - ε=0.100
# Episodio 618/800 - Recompensa: 1383.0 - ε=0.100
# Episodio 619/800 - Recompensa: 2426.0 - ε=0.100
# Episodio 620/800 - Recompensa: 1820.0 - ε=0.100
# Episodio 621/800 - Recompensa: 1479.0 - ε=0.100
# Episodio 622/800 - Recompensa: 1965.0 - ε=0.100
# Episodio 623/800 - Recompensa: 1421.0 - ε=0.100
# Episodio 624/800 - Recompensa: 2519.0 - ε=0.100
# Episodio 625/800 - Recompensa: 1484.0 - ε=0.100
# Episodio 626/800 - Recompensa: 1962.0 - ε=0.100
# Episodio 627/800 - Recompensa: 2029.0 - ε=0.100
# Episodio 628/800 - Recompensa: 2751.0 - ε=0.100
# Episodio 629/800 - Recompensa: 2355.0 - ε=0.100
# Episodio 630/800 - Recompensa: 2270.0 - ε=0.100
# Episodio 631/800 - Recompensa: 1968.0 - ε=0.100
# Episodio 632/800 - Recompensa: 2026.0 - ε=0.100
# Episodio 633/800 - Recompensa: 2224.0 - ε=0.100
# Episodio 634/800 - Recompensa: 1474.0 - ε=0.100
# Episodio 635/800 - Recompensa: 1916.0 - ε=0.100
# Episodio 636/800 - Recompensa: 1848.0 - ε=0.100
# Episodio 637/800 - Recompensa: 2607.0 - ε=0.100
# Episodio 638/800 - Recompensa: 1130.0 - ε=0.100
# Episodio 639/800 - Recompensa: 1606.0 - ε=0.100
# Episodio 640/800 - Recompensa: 635.0 - ε=0.100
# Episodio 641/800 - Recompensa: 2390.0 - ε=0.100
# Episodio 642/800 - Recompensa: 1564.0 - ε=0.100
# Episodio 643/800 - Recompensa: 1821.0 - ε=0.100
# Episodio 644/800 - Recompensa: 608.0 - ε=0.100
# Episodio 645/800 - Recompensa: 1861.0 - ε=0.100
# Episodio 646/800 - Recompensa: 1760.0 - ε=0.100
# Episodio 647/800 - Recompensa: 2020.0 - ε=0.100
# Episodio 648/800 - Recompensa: 2225.0 - ε=0.100
# Episodio 649/800 - Recompensa: 2325.0 - ε=0.100
# Episodio 650/800 - Recompensa: 701.0 - ε=0.100
# Episodio 651/800 - Recompensa: 1430.0 - ε=0.100
# Episodio 652/800 - Recompensa: 2256.0 - ε=0.100
# Episodio 653/800 - Recompensa: 2891.0 - ε=0.100
# Episodio 654/800 - Recompensa: 1954.0 - ε=0.100
# Episodio 655/800 - Recompensa: 2532.0 - ε=0.100
# Episodio 656/800 - Recompensa: 2944.0 - ε=0.100
# Episodio 657/800 - Recompensa: 2020.0 - ε=0.100
# Episodio 658/800 - Recompensa: 2187.0 - ε=0.100
# Episodio 659/800 - Recompensa: 1463.0 - ε=0.100
# Episodio 660/800 - Recompensa: 696.0 - ε=0.100
# Episodio 661/800 - Recompensa: 2392.0 - ε=0.100
# Episodio 662/800 - Recompensa: 1959.0 - ε=0.100
# Episodio 663/800 - Recompensa: 1785.0 - ε=0.100
# Episodio 664/800 - Recompensa: 1473.0 - ε=0.100
# Episodio 665/800 - Recompensa: 2196.0 - ε=0.100
# Episodio 666/800 - Recompensa: 1616.0 - ε=0.100
# Episodio 667/800 - Recompensa: 1764.0 - ε=0.100
# Episodio 668/800 - Recompensa: 2583.0 - ε=0.100
# Episodio 669/800 - Recompensa: 1968.0 - ε=0.100
# Episodio 670/800 - Recompensa: 1829.0 - ε=0.100
# Episodio 671/800 - Recompensa: 1415.0 - ε=0.100
# Episodio 672/800 - Recompensa: 2229.0 - ε=0.100
# Episodio 673/800 - Recompensa: 1485.0 - ε=0.100
# Episodio 674/800 - Recompensa: 2026.0 - ε=0.100
# Episodio 675/800 - Recompensa: 2017.0 - ε=0.100
# Episodio 676/800 - Recompensa: 1230.0 - ε=0.100
# Episodio 677/800 - Recompensa: 1634.0 - ε=0.100
# Episodio 678/800 - Recompensa: 1441.0 - ε=0.100
# Episodio 679/800 - Recompensa: 1455.0 - ε=0.100
# Episodio 680/800 - Recompensa: 1573.0 - ε=0.100
# Episodio 681/800 - Recompensa: 1658.0 - ε=0.100
# Episodio 682/800 - Recompensa: 1550.0 - ε=0.100
# Episodio 683/800 - Recompensa: 1779.0 - ε=0.100
# Episodio 684/800 - Recompensa: 1779.0 - ε=0.100
# Episodio 685/800 - Recompensa: 2601.0 - ε=0.100
# Episodio 686/800 - Recompensa: 2523.0 - ε=0.100
# Episodio 687/800 - Recompensa: 1435.0 - ε=0.100
# Episodio 688/800 - Recompensa: 2095.0 - ε=0.100
# Episodio 689/800 - Recompensa: 1386.0 - ε=0.100
# Episodio 690/800 - Recompensa: 1648.0 - ε=0.100
# Episodio 691/800 - Recompensa: 2418.0 - ε=0.100
# Episodio 692/800 - Recompensa: 2216.0 - ε=0.100
# Episodio 693/800 - Recompensa: 2195.0 - ε=0.100
# Episodio 694/800 - Recompensa: 2286.0 - ε=0.100
# Episodio 695/800 - Recompensa: 2282.0 - ε=0.100
# Episodio 696/800 - Recompensa: 2714.0 - ε=0.100
# Episodio 697/800 - Recompensa: 2703.0 - ε=0.100
# Episodio 698/800 - Recompensa: 3140.0 - ε=0.100
# Episodio 699/800 - Recompensa: 1484.0 - ε=0.100
# Episodio 700/800 - Recompensa: 2611.0 - ε=0.100
# Episodio 701/800 - Recompensa: 2194.0 - ε=0.100
# Episodio 702/800 - Recompensa: 2418.0 - ε=0.100
# Episodio 703/800 - Recompensa: 1677.0 - ε=0.100
# Episodio 704/800 - Recompensa: 1611.0 - ε=0.100
# Episodio 705/800 - Recompensa: 2663.0 - ε=0.100
# Episodio 706/800 - Recompensa: 1122.0 - ε=0.100
# Episodio 707/800 - Recompensa: 1511.0 - ε=0.100
# Episodio 708/800 - Recompensa: 1600.0 - ε=0.100
# Episodio 709/800 - Recompensa: 1448.0 - ε=0.100
# Episodio 710/800 - Recompensa: 3160.0 - ε=0.100
# Episodio 711/800 - Recompensa: 1890.0 - ε=0.100
# Episodio 712/800 - Recompensa: 2426.0 - ε=0.100
# Episodio 713/800 - Recompensa: 1424.0 - ε=0.100
# Episodio 714/800 - Recompensa: 2049.0 - ε=0.100
# Episodio 715/800 - Recompensa: 1790.0 - ε=0.100
# Episodio 716/800 - Recompensa: 1312.0 - ε=0.100
# Episodio 717/800 - Recompensa: 2753.0 - ε=0.100
# Episodio 718/800 - Recompensa: 2163.0 - ε=0.100
# Episodio 719/800 - Recompensa: 2636.0 - ε=0.100
# Episodio 720/800 - Recompensa: 1412.0 - ε=0.100
# Episodio 721/800 - Recompensa: 2747.0 - ε=0.100
# Episodio 722/800 - Recompensa: 2687.0 - ε=0.100
# Episodio 723/800 - Recompensa: 1513.0 - ε=0.100
# Episodio 724/800 - Recompensa: 1901.0 - ε=0.100
# Episodio 725/800 - Recompensa: 1580.0 - ε=0.100
# Episodio 726/800 - Recompensa: 2040.0 - ε=0.100
# Episodio 727/800 - Recompensa: 1410.0 - ε=0.100
# Episodio 728/800 - Recompensa: 608.0 - ε=0.100
# Episodio 729/800 - Recompensa: 2299.0 - ε=0.100
# Episodio 730/800 - Recompensa: 2158.0 - ε=0.100
# Episodio 731/800 - Recompensa: 1835.0 - ε=0.100
# Episodio 732/800 - Recompensa: 608.0 - ε=0.100
# Episodio 733/800 - Recompensa: 1450.0 - ε=0.100
# Episodio 734/800 - Recompensa: 730.0 - ε=0.100
# Episodio 735/800 - Recompensa: 2036.0 - ε=0.100
# Episodio 736/800 - Recompensa: 1803.0 - ε=0.100
# Episodio 737/800 - Recompensa: 2645.0 - ε=0.100
# Episodio 738/800 - Recompensa: 1079.0 - ε=0.100
# Episodio 739/800 - Recompensa: 1931.0 - ε=0.100
# Episodio 740/800 - Recompensa: 2223.0 - ε=0.100
# Episodio 741/800 - Recompensa: 2094.0 - ε=0.100
# Episodio 742/800 - Recompensa: 2029.0 - ε=0.100
# Episodio 743/800 - Recompensa: 2179.0 - ε=0.100
# Episodio 744/800 - Recompensa: 2072.0 - ε=0.100
# Episodio 745/800 - Recompensa: 1634.0 - ε=0.100
# Episodio 746/800 - Recompensa: 2638.0 - ε=0.100
# Episodio 747/800 - Recompensa: 1117.0 - ε=0.100
# Episodio 748/800 - Recompensa: 1500.0 - ε=0.100
# Episodio 749/800 - Recompensa: 1780.0 - ε=0.100
# Episodio 750/800 - Recompensa: 2048.0 - ε=0.100
# Episodio 751/800 - Recompensa: 1897.0 - ε=0.100
# Episodio 752/800 - Recompensa: 1068.0 - ε=0.100
# Episodio 753/800 - Recompensa: 2983.0 - ε=0.100
# Episodio 754/800 - Recompensa: 1467.0 - ε=0.100
# Episodio 755/800 - Recompensa: 1479.0 - ε=0.100
# Episodio 756/800 - Recompensa: 1623.0 - ε=0.100
# Episodio 757/800 - Recompensa: 1649.0 - ε=0.100
# Episodio 758/800 - Recompensa: 3111.0 - ε=0.100
# Episodio 759/800 - Recompensa: 1961.0 - ε=0.100
# Episodio 760/800 - Recompensa: 2422.0 - ε=0.100
# Episodio 761/800 - Recompensa: 1906.0 - ε=0.100
# Episodio 762/800 - Recompensa: 1770.0 - ε=0.100
# Episodio 763/800 - Recompensa: 1551.0 - ε=0.100
# Episodio 764/800 - Recompensa: 2052.0 - ε=0.100
# Episodio 765/800 - Recompensa: 1546.0 - ε=0.100
# Episodio 766/800 - Recompensa: 1514.0 - ε=0.100
# Episodio 767/800 - Recompensa: 2522.0 - ε=0.100
# Episodio 768/800 - Recompensa: 2212.0 - ε=0.100
# Episodio 769/800 - Recompensa: 2307.0 - ε=0.100
# Episodio 770/800 - Recompensa: 1422.0 - ε=0.100
# Episodio 771/800 - Recompensa: 1974.0 - ε=0.100
# Episodio 772/800 - Recompensa: 2111.0 - ε=0.100
# Episodio 773/800 - Recompensa: 1712.0 - ε=0.100
# Episodio 774/800 - Recompensa: 2151.0 - ε=0.100
# Episodio 775/800 - Recompensa: 2609.0 - ε=0.100
# Episodio 776/800 - Recompensa: 1465.0 - ε=0.100
# Episodio 777/800 - Recompensa: 2076.0 - ε=0.100
# Episodio 778/800 - Recompensa: 1851.0 - ε=0.100
# Episodio 779/800 - Recompensa: 1730.0 - ε=0.100
# Episodio 780/800 - Recompensa: 2129.0 - ε=0.100
# Episodio 781/800 - Recompensa: 2023.0 - ε=0.100
# Episodio 782/800 - Recompensa: 1969.0 - ε=0.100
# Episodio 783/800 - Recompensa: 1851.0 - ε=0.100
# Episodio 784/800 - Recompensa: 2938.0 - ε=0.100
# Episodio 785/800 - Recompensa: 2366.0 - ε=0.100
# Episodio 786/800 - Recompensa: 1581.0 - ε=0.100
# Episodio 787/800 - Recompensa: 1505.0 - ε=0.100
# Episodio 788/800 - Recompensa: 1724.0 - ε=0.100
# Episodio 789/800 - Recompensa: 1633.0 - ε=0.100
# Episodio 790/800 - Recompensa: 2574.0 - ε=0.100
# Episodio 791/800 - Recompensa: 1228.0 - ε=0.100
# Episodio 792/800 - Recompensa: 2527.0 - ε=0.100
# Episodio 793/800 - Recompensa: 2261.0 - ε=0.100
# Episodio 794/800 - Recompensa: 1559.0 - ε=0.100
# Episodio 795/800 - Recompensa: 1923.0 - ε=0.100
# Episodio 796/800 - Recompensa: 711.0 - ε=0.100
# Episodio 797/800 - Recompensa: 2022.0 - ε=0.100
# Episodio 798/800 - Recompensa: 2109.0 - ε=0.100
# Episodio 799/800 - Recompensa: 1857.0 - ε=0.100
# Episodio 800/800 - Recompensa: 2087.0 - ε=0.100

# %%
# Crear un nuevo entorno para reproducción
video_env = gym_super_mario_bros.make("SuperMarioBros-v0")
video_env = JoypadSpace(video_env, SIMPLE_MOVEMENT)

frames = []
obs = video_env.reset()
state = preprocess_frame(obs)
state_stack = np.stack([state]*4, axis=0)

done = False
while not done:
    with torch.no_grad():
        state_tensor = torch.tensor(state_stack, dtype=torch.float32, device=device).unsqueeze(0)
        action = policy_net(state_tensor).argmax().item()  # siempre la mejor acción
    next_obs, reward, done, info = video_env.step(action)
    frame = video_env.render(mode='rgb_array')
    frames.append(frame)
    
    next_frame = preprocess_frame(next_obs)
    state_stack = np.concatenate([state_stack[1:], next_frame[np.newaxis, ...]], axis=0)

video_env.close()

# Guardar video con OpenCV
height, width, layers = frames[0].shape
video_name = 'mario_final.mp4'
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
video = cv2.VideoWriter(video_name, fourcc, 30, (width, height))

for f in frames:
    # Convertir RGB a BGR para OpenCV
    video.write(cv2.cvtColor(f, cv2.COLOR_RGB2BGR))
video.release()
print("Video guardado como", video_name)
# Out:
# /usr/local/lib/python3.11/dist-packages/gym/envs/registration.py:593: UserWarning: WARN: The environment SuperMarioBros-v0 is out of date. You should consider upgrading to version `v3`.
#   logger.warn(
# /usr/local/lib/python3.11/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.11/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.11/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# /usr/local/lib/python3.11/dist-packages/gym/utils/passive_env_checker.py:280: UserWarning: WARN: No render modes was declared in the environment (env.metadata['render_modes'] is None or not defined), you may have trouble when calling `.render()`.
#   logger.warn(
# Video guardado como mario_final.mp4

# %%
import imageio
from IPython.display import HTML
from base64 import b64encode

# Crear entorno limpio SOLO para grabar video
video_env = gym_super_mario_bros.make("SuperMarioBros-v0")
video_env = JoypadSpace(video_env, SIMPLE_MOVEMENT)

frames = []
obs = video_env.reset()
state = preprocess_frame(obs)
state_stack = np.stack([state]*4, axis=0)

done = False
while not done:
    with torch.no_grad():
        state_tensor = torch.tensor(state_stack, dtype=torch.float32, device=device).unsqueeze(0)
        action = policy_net(state_tensor).argmax().item()
    
    next_obs, reward, done, info = video_env.step(action)

    # ⚠️ Captura directa desde la pantalla del entorno
    if hasattr(video_env.unwrapped, "screen"):
        frame = video_env.unwrapped.screen.copy()
        frames.append(frame)

    next_frame = preprocess_frame(next_obs)
    state_stack = np.concatenate([state_stack[1:], next_frame[np.newaxis, ...]], axis=0)

video_env.close()

# Guardar video
video_name = "mario_final.mp4"
imageio.mimsave(video_name, frames, fps=30)
print("✅ Video guardado como:", video_name)

# Mostrar el video directamente
def display_video(filename):
    with open(filename, "rb") as f:
        video_data = f.read()
    data_url = "data:video/mp4;base64," + b64encode(video_data).decode()
    return HTML(f"""
        <video width="640" height="480" controls autoplay loop>
            <source src="{data_url}" type="video/mp4">
        </video>
    """)

display_video(video_name)
# Out:
# ✅ Video guardado como: mario_final.mp4
#         <video width="640" height="480" controls autoplay loop>
#             <source src="data:video/mp4;base64,..." type="video/mp4">
#         </video>
