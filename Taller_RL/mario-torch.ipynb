# %%
# !pip install gym-super-mario-bros==7.4.0 nes-py pyvirtualdisplay
# !apt-get update && apt-get install -y xvfb ffmpeg
# Out:
# Collecting gym-super-mario-bros==7.4.0
#   Downloading gym_super_mario_bros-7.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting nes-py
#   Downloading nes_py-8.2.1.tar.gz (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.7/77.7 kB 2.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl.metadata (943 bytes)
# Requirement already satisfied: gym>=0.17.2 in /usr/local/lib/python3.11/dist-packages (from nes-py) (0.25.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.11/dist-packages (from nes-py) (1.26.4)
# Collecting pyglet<=1.5.21,>=1.4.0 (from nes-py)
#   Downloading pyglet-1.5.21-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: tqdm>=4.48.2 in /usr/local/lib/python3.11/dist-packages (from nes-py) (4.67.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gym>=0.17.2->nes-py) (3.1.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.11/dist-packages (from gym>=0.17.2->nes-py) (0.0.8)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.5->nes-py) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.5->nes-py) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.5->nes-py) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.5->nes-py) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.5->nes-py) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.5->nes-py) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.18.5->nes-py) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.18.5->nes-py) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.18.5->nes-py) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.18.5->nes-py) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.18.5->nes-py) (2024.2.0)
# Downloading gym_super_mario_bros-7.4.0-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 kB 10.0 MB/s eta 0:00:00
# Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Downloading pyglet-1.5.21-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 37.7 MB/s eta 0:00:00
# Building wheels for collected packages: nes-py
#   Building wheel for nes-py (setup.py) ... done
#   Created wheel for nes-py: filename=nes_py-8.2.1-cp311-cp311-linux_x86_64.whl size=535719 sha256=dcb30ac945576034280eb39f02c834f1aa18e62685721d545ea8944db680de3e
#   Stored in directory: /root/.cache/pip/wheels/be/b4/5a/68b9155f1d2380af0e359c71efd4c70518555be4c2f577f1d3
# Successfully built nes-py
# Installing collected packages: pyvirtualdisplay, pyglet, nes-py, gym-super-mario-bros
# Successfully installed gym-super-mario-bros-7.4.0 nes-py-8.2.1 pyglet-1.5.21 pyvirtualdisplay-3.0
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [79.8 kB]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,804 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,081 kB]
# Get:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [4,763 kB]
# Get:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:14 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,752 kB]
# Get:15 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease [24.6 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,262 kB]
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [48.5 kB]
# Get:18 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,092 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [56.4 kB]
# Get:20 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [33.2 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,404 kB]
# Get:22 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy/main amd64 Packages [51.0 kB]
# Get:23 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 Packages [75.1 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [4,917 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,566 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [35.2 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [83.2 kB]
# Fetched 33.6 MB in 3s (12.7 MB/s)
#
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
#
#
#
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# The following packages will be upgraded:
#   xserver-common xvfb
# 2 upgraded, 0 newly installed, 0 to remove and 198 not upgraded.
# Need to get 896 kB of archives.
# After this operation, 0 B of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-common all 2:21.1.4-2ubuntu1.7~22.04.15 [29.5 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 xvfb amd64 2:21.1.4-2ubuntu1.7~22.04.15 [866 kB]
# Fetched 896 kB in 1s (721 kB/s)
# (Reading database ... 129184 files and directories currently installed.)
# Preparing to unpack .../xserver-common_2%3a21.1.4-2ubuntu1.7~22.04.15_all.deb ...
# Unpacking xserver-common (2:21.1.4-2ubuntu1.7~22.04.15) over (2:21.1.4-2ubuntu1.7~22.04.14) ...
# Preparing to unpack .../xvfb_2%3a21.1.4-2ubuntu1.7~22.04.15_amd64.deb ...
# Unpacking xvfb (2:21.1.4-2ubuntu1.7~22.04.15) over (2:21.1.4-2ubuntu1.7~22.04.14) ...
# Setting up xserver-common (2:21.1.4-2ubuntu1.7~22.04.15) ...
# Setting up xvfb (2:21.1.4-2ubuntu1.7~22.04.15) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
import random
import numpy as np
import cv2
import gym
import gym_super_mario_bros
from nes_py.wrappers import JoypadSpace
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT
from collections import deque
from pyvirtualdisplay import Display

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# Configurar dispositivo (GPU si está disponible)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Usando dispositivo:", device)

# Inicializar un display virtual para render (necesario para guardar video)
display = Display(visible=0, size=(1400, 900))
display.start()
# Out:
# Usando dispositivo: cuda

# %%
# Crear entorno (puede ser "SuperMarioBros-v0" o un nivel específico como "SuperMarioBros-1-1-v0")
env = gym_super_mario_bros.make("SuperMarioBros-v0")
env = JoypadSpace(env, SIMPLE_MOVEMENT)
n_actions = env.action_space.n
print("Número de acciones:", n_actions)
# Out:
# /usr/local/lib/python3.11/dist-packages/gym/envs/registration.py:593: UserWarning: WARN: The environment SuperMarioBros-v0 is out of date. You should consider upgrading to version `v3`.
#   logger.warn(
# Número de acciones: 7
# /usr/local/lib/python3.11/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.11/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(

# %%
def preprocess_frame(frame):
    """Convierte un fotograma RGB a escala de grises 84x84."""
    gray = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
    resized = cv2.resize(gray, (84, 84), interpolation=cv2.INTER_AREA)
    normalized = resized.astype(np.float32) / 255.0
    return normalized  # matriz 84x84

# Ejemplo: obtener el primer estado (apilando 4 veces el fotograma inicial)
obs = env.reset()
state = preprocess_frame(obs)
state_stack = np.stack([state] * 4, axis=0)  # shape = (4, 84, 84)

# %%
class DQN(nn.Module):
    def __init__(self, input_channels, num_actions):
        super(DQN, self).__init__()
        # Capas convolucionales
        self.conv1 = nn.Conv2d(input_channels, 32, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
        # Capa totalmente conectada
        self.fc_input_dim = self._get_conv_output((input_channels, 84, 84))
        self.fc1 = nn.Linear(self.fc_input_dim, 512)
        self.fc2 = nn.Linear(512, num_actions)
    
    def _get_conv_output(self, shape):
        # Función auxiliar para calcular tamaño de salida del bloque conv
        o = torch.zeros(1, *shape)
        o = self.conv1(o)
        o = self.conv2(o)
        o = self.conv3(o)
        return int(np.prod(o.size()))
    
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        return self.fc2(x)

# Crear redes en línea (policy_net) y target (target_net)
policy_net = DQN(input_channels=4, num_actions=n_actions).to(device)
target_net = DQN(input_channels=4, num_actions=n_actions).to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()  # Red target en modo evaluación
# Out:
# DQN(
#   (conv1): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#   (conv2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=3136, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=7, bias=True)
# )

# %%
class ReplayBuffer:
    def __init__(self, capacity):
        self.capacity = capacity
        self.buffer = deque(maxlen=capacity)
    
    def push(self, state, action, reward, next_state, done):
        # Se clonan arrays para evitar referencias mutables
        state = np.array(state, copy=False)
        next_state = np.array(next_state, copy=False)
        self.buffer.append((state, action, reward, next_state, done))
    
    def sample(self, batch_size):
        # Muestra al azar un batch de transiciones
        transitions = random.sample(self.buffer, batch_size)
        states, actions, rewards, next_states, dones = zip(*transitions)
        return np.array(states), actions, rewards, np.array(next_states), dones
    
    def __len__(self):
        return len(self.buffer)

# Inicializar memoria
memory = ReplayBuffer(capacity=100000)

# %%
# Hiperparámetros
num_episodes = 400            # número de episodios de entrenamiento
max_steps_per_episode = 5000   # tope de pasos por episodio
batch_size = 32
gamma = 0.99                   # factor de descuento
learning_rate = 1e-4
epsilon_start = 1.0
epsilon_end = 0.1
epsilon_decay = 200000         # pasos para decaer ε
target_update = 10             # episodios para actualizar target_net

optimizer = optim.Adam(policy_net.parameters(), lr=learning_rate)

steps_done = 0
epsilon = epsilon_start

for episode in range(num_episodes):
    obs = env.reset()
    state = preprocess_frame(obs)
    state_stack = np.stack([state]*4, axis=0)  # inicializar stack de 4 frames
    total_reward = 0
    
    for t in range(max_steps_per_episode):
        # ε-greedy: decidir acción
        if random.random() < epsilon:
            action = random.randrange(n_actions)
        else:
            with torch.no_grad():
                state_tensor = torch.tensor(state_stack, dtype=torch.float32, device=device).unsqueeze(0)
                q_values = policy_net(state_tensor)
                action = q_values.argmax().item()
        
        # Ejecutar acción en el entorno
        next_obs, reward, done, info = env.step(action)
        next_frame = preprocess_frame(next_obs)
        next_state_stack = np.concatenate([state_stack[1:], next_frame[np.newaxis, ...]], axis=0)
        
        # Almacenar transición en memoria
        memory.push(state_stack, action, reward, next_state_stack, done)
        total_reward += reward
        state_stack = next_state_stack
        
        # Actualizar ε
        steps_done += 1
        epsilon = max(epsilon_end, epsilon_start - steps_done / epsilon_decay)
        
        # Realizar optimización si hay muestras suficientes
        if len(memory) >= batch_size:
            states, actions, rewards, next_states, dones = memory.sample(batch_size)
            
            # Convertir a tensores
            states_v = torch.tensor(states, dtype=torch.float32, device=device)
            next_states_v = torch.tensor(next_states, dtype=torch.float32, device=device)
            actions_v = torch.tensor(actions, dtype=torch.int64, device=device).unsqueeze(1)
            rewards_v = torch.tensor(rewards, dtype=torch.float32, device=device)
            dones_v = torch.tensor(dones, dtype=torch.float32, device=device)
            
            # Calcular Q(s,a) con red online
            q_values = policy_net(states_v).gather(1, actions_v).squeeze(1)
            # Seleccionar acciones con red online para siguiente estado (Double DQN)
            next_actions = policy_net(next_states_v).argmax(dim=1, keepdim=True)
            # Calcular Q target con red target
            next_q_values = target_net(next_states_v).gather(1, next_actions).squeeze(1)
            expected_q_values = rewards_v + gamma * next_q_values * (1 - dones_v)
            
            # Pérdida Huber (Smooth L1) para estabilidad
            loss = F.smooth_l1_loss(q_values, expected_q_values.detach())
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        
        if done:
            break
    
    # Actualizar red target cada ciertos episodios
    if episode % target_update == 0:
        target_net.load_state_dict(policy_net.state_dict())
    
    print(f"Episodio {episode+1}/{num_episodes} - Recompensa: {total_reward:.1f} - ε={epsilon:.3f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/gym/utils/passive_env_checker.py:227: DeprecationWarning: WARN: Core environment is written in old step API which returns one bool instead of two. It is recommended to rewrite the environment with new step API.
#   logger.deprecation(
# /usr/local/lib/python3.11/dist-packages/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(done, (bool, np.bool8)):
# Episodio 1/400 - Recompensa: 432.0 - ε=0.975
# Episodio 2/400 - Recompensa: 304.0 - ε=0.950
# Episodio 3/400 - Recompensa: 694.0 - ε=0.948
# Episodio 4/400 - Recompensa: 304.0 - ε=0.923
# Episodio 5/400 - Recompensa: 559.0 - ε=0.898
# Episodio 6/400 - Recompensa: 798.0 - ε=0.873
# Episodio 7/400 - Recompensa: 956.0 - ε=0.848
# Episodio 8/400 - Recompensa: 303.0 - ε=0.823
# Episodio 9/400 - Recompensa: 432.0 - ε=0.798
# Episodio 10/400 - Recompensa: 432.0 - ε=0.773
# Episodio 11/400 - Recompensa: 304.0 - ε=0.748
# Episodio 12/400 - Recompensa: 922.0 - ε=0.723
# Episodio 13/400 - Recompensa: 432.0 - ε=0.698
# Episodio 14/400 - Recompensa: 304.0 - ε=0.673
# Episodio 15/400 - Recompensa: 432.0 - ε=0.648
# Episodio 16/400 - Recompensa: 432.0 - ε=0.623
# Episodio 17/400 - Recompensa: 1183.0 - ε=0.598
# Episodio 18/400 - Recompensa: 432.0 - ε=0.573
# Episodio 19/400 - Recompensa: 432.0 - ε=0.548
# Episodio 20/400 - Recompensa: 432.0 - ε=0.523
# Episodio 21/400 - Recompensa: 1099.0 - ε=0.498
# Episodio 22/400 - Recompensa: 432.0 - ε=0.473
# Episodio 23/400 - Recompensa: 1449.0 - ε=0.464
# Episodio 24/400 - Recompensa: 432.0 - ε=0.439
# Episodio 25/400 - Recompensa: 432.0 - ε=0.414
# Episodio 26/400 - Recompensa: 1276.0 - ε=0.389
# Episodio 27/400 - Recompensa: 431.0 - ε=0.364
# Episodio 28/400 - Recompensa: 432.0 - ε=0.339
# Episodio 29/400 - Recompensa: 1047.0 - ε=0.329
# Episodio 30/400 - Recompensa: 432.0 - ε=0.304
# Episodio 31/400 - Recompensa: 1493.0 - ε=0.288
# Episodio 32/400 - Recompensa: 1991.0 - ε=0.269
# Episodio 33/400 - Recompensa: 1722.0 - ε=0.244
# Episodio 34/400 - Recompensa: 1075.0 - ε=0.238
# Episodio 35/400 - Recompensa: 1457.0 - ε=0.225
# Episodio 36/400 - Recompensa: 2389.0 - ε=0.200
# Episodio 37/400 - Recompensa: 1372.0 - ε=0.188
# Episodio 38/400 - Recompensa: 801.0 - ε=0.163
# Episodio 39/400 - Recompensa: 2126.0 - ε=0.138
# Episodio 40/400 - Recompensa: 696.0 - ε=0.136
# Episodio 41/400 - Recompensa: 1753.0 - ε=0.111
# Episodio 42/400 - Recompensa: 2148.0 - ε=0.100
# Episodio 43/400 - Recompensa: 1049.0 - ε=0.100
# Episodio 44/400 - Recompensa: 821.0 - ε=0.100
# Episodio 45/400 - Recompensa: 1065.0 - ε=0.100
# Episodio 46/400 - Recompensa: 1848.0 - ε=0.100
# Episodio 47/400 - Recompensa: 1481.0 - ε=0.100
# Episodio 48/400 - Recompensa: 1463.0 - ε=0.100
# Episodio 49/400 - Recompensa: 1109.0 - ε=0.100
# Episodio 50/400 - Recompensa: 1389.0 - ε=0.100
# Episodio 51/400 - Recompensa: 1438.0 - ε=0.100
# Episodio 52/400 - Recompensa: 1051.0 - ε=0.100
# Episodio 53/400 - Recompensa: 1170.0 - ε=0.100
# Episodio 54/400 - Recompensa: 1917.0 - ε=0.100
# Episodio 55/400 - Recompensa: 1950.0 - ε=0.100
# Episodio 56/400 - Recompensa: 1250.0 - ε=0.100
# Episodio 57/400 - Recompensa: 1514.0 - ε=0.100
# Episodio 58/400 - Recompensa: 1068.0 - ε=0.100
# Episodio 59/400 - Recompensa: 1649.0 - ε=0.100
# Episodio 60/400 - Recompensa: 2254.0 - ε=0.100
# Episodio 61/400 - Recompensa: 1434.0 - ε=0.100
# Episodio 62/400 - Recompensa: 1452.0 - ε=0.100
# Episodio 63/400 - Recompensa: 1484.0 - ε=0.100
# Episodio 64/400 - Recompensa: 1452.0 - ε=0.100
# Episodio 65/400 - Recompensa: 2152.0 - ε=0.100
# Episodio 66/400 - Recompensa: 1486.0 - ε=0.100
# Episodio 67/400 - Recompensa: 1492.0 - ε=0.100
# Episodio 68/400 - Recompensa: 840.0 - ε=0.100
# Episodio 69/400 - Recompensa: 1140.0 - ε=0.100
# Episodio 70/400 - Recompensa: 1614.0 - ε=0.100
# Episodio 71/400 - Recompensa: 1893.0 - ε=0.100
# Episodio 72/400 - Recompensa: 1084.0 - ε=0.100
# Episodio 73/400 - Recompensa: 728.0 - ε=0.100
# Episodio 74/400 - Recompensa: 2620.0 - ε=0.100
# Episodio 75/400 - Recompensa: 1940.0 - ε=0.100
# Episodio 76/400 - Recompensa: 1196.0 - ε=0.100
# Episodio 77/400 - Recompensa: 1931.0 - ε=0.100
# Episodio 78/400 - Recompensa: 711.0 - ε=0.100
# Episodio 79/400 - Recompensa: 2164.0 - ε=0.100
# Episodio 80/400 - Recompensa: 864.0 - ε=0.100
# Episodio 81/400 - Recompensa: 1849.0 - ε=0.100
# Episodio 82/400 - Recompensa: 2262.0 - ε=0.100
# Episodio 83/400 - Recompensa: 1912.0 - ε=0.100
# Episodio 84/400 - Recompensa: 1890.0 - ε=0.100
# Episodio 85/400 - Recompensa: 1083.0 - ε=0.100
# Episodio 86/400 - Recompensa: 1418.0 - ε=0.100
# Episodio 87/400 - Recompensa: 2135.0 - ε=0.100
# Episodio 88/400 - Recompensa: 1716.0 - ε=0.100
# Episodio 89/400 - Recompensa: 1447.0 - ε=0.100
# Episodio 90/400 - Recompensa: 2139.0 - ε=0.100
# Episodio 91/400 - Recompensa: 1787.0 - ε=0.100
# Episodio 92/400 - Recompensa: 1386.0 - ε=0.100
# Episodio 93/400 - Recompensa: 1552.0 - ε=0.100
# Episodio 94/400 - Recompensa: 2475.0 - ε=0.100
# Episodio 95/400 - Recompensa: 1427.0 - ε=0.100
# Episodio 96/400 - Recompensa: 2677.0 - ε=0.100
# Episodio 97/400 - Recompensa: 1655.0 - ε=0.100
# Episodio 98/400 - Recompensa: 1884.0 - ε=0.100
# Episodio 99/400 - Recompensa: 1965.0 - ε=0.100
# Episodio 100/400 - Recompensa: 1563.0 - ε=0.100
# Episodio 101/400 - Recompensa: 726.0 - ε=0.100
# Episodio 102/400 - Recompensa: 2287.0 - ε=0.100
# Episodio 103/400 - Recompensa: 1953.0 - ε=0.100
# Episodio 104/400 - Recompensa: 2304.0 - ε=0.100
# Episodio 105/400 - Recompensa: 2253.0 - ε=0.100
# Episodio 106/400 - Recompensa: 1514.0 - ε=0.100
# Episodio 107/400 - Recompensa: 1421.0 - ε=0.100
# Episodio 108/400 - Recompensa: 2127.0 - ε=0.100
# Episodio 109/400 - Recompensa: 1681.0 - ε=0.100
# Episodio 110/400 - Recompensa: 1972.0 - ε=0.100
# Episodio 111/400 - Recompensa: 1561.0 - ε=0.100
# Episodio 112/400 - Recompensa: 1569.0 - ε=0.100
# Episodio 113/400 - Recompensa: 1694.0 - ε=0.100
# Episodio 114/400 - Recompensa: 1815.0 - ε=0.100
# Episodio 115/400 - Recompensa: 2363.0 - ε=0.100
# Episodio 116/400 - Recompensa: 2900.0 - ε=0.100
# Episodio 117/400 - Recompensa: 1810.0 - ε=0.100
# Episodio 118/400 - Recompensa: 1800.0 - ε=0.100
# Episodio 119/400 - Recompensa: 2585.0 - ε=0.100
# Episodio 120/400 - Recompensa: 1365.0 - ε=0.100
# Episodio 121/400 - Recompensa: 2257.0 - ε=0.100
# Episodio 122/400 - Recompensa: 1600.0 - ε=0.100
# Episodio 123/400 - Recompensa: 1592.0 - ε=0.100
# Episodio 124/400 - Recompensa: 1483.0 - ε=0.100
# Episodio 125/400 - Recompensa: 1583.0 - ε=0.100
# Episodio 126/400 - Recompensa: 1554.0 - ε=0.100
# Episodio 127/400 - Recompensa: 1442.0 - ε=0.100
# Episodio 128/400 - Recompensa: 2267.0 - ε=0.100
# Episodio 129/400 - Recompensa: 1410.0 - ε=0.100
# Episodio 130/400 - Recompensa: 1975.0 - ε=0.100
# Episodio 131/400 - Recompensa: 1855.0 - ε=0.100
# Episodio 132/400 - Recompensa: 1662.0 - ε=0.100
# Episodio 133/400 - Recompensa: 1439.0 - ε=0.100
# Episodio 134/400 - Recompensa: 2994.0 - ε=0.100
# Episodio 135/400 - Recompensa: 2140.0 - ε=0.100
# Episodio 136/400 - Recompensa: 1978.0 - ε=0.100
# Episodio 137/400 - Recompensa: 1420.0 - ε=0.100
# Episodio 138/400 - Recompensa: 2491.0 - ε=0.100
# Episodio 139/400 - Recompensa: 1481.0 - ε=0.100
# Episodio 140/400 - Recompensa: 1845.0 - ε=0.100
# Episodio 141/400 - Recompensa: 3009.0 - ε=0.100
# Episodio 142/400 - Recompensa: 1353.0 - ε=0.100
# Episodio 143/400 - Recompensa: 1274.0 - ε=0.100
# Episodio 144/400 - Recompensa: 1464.0 - ε=0.100
# Episodio 145/400 - Recompensa: 1686.0 - ε=0.100
# Episodio 146/400 - Recompensa: 1867.0 - ε=0.100
# Episodio 147/400 - Recompensa: 1575.0 - ε=0.100
# Episodio 148/400 - Recompensa: 2291.0 - ε=0.100
# Episodio 149/400 - Recompensa: 1622.0 - ε=0.100
# Episodio 150/400 - Recompensa: 2410.0 - ε=0.100
# Episodio 151/400 - Recompensa: 1937.0 - ε=0.100
# Episodio 152/400 - Recompensa: 1819.0 - ε=0.100
# Episodio 153/400 - Recompensa: 1497.0 - ε=0.100
# Episodio 154/400 - Recompensa: 1731.0 - ε=0.100
# Episodio 155/400 - Recompensa: 1879.0 - ε=0.100
# Episodio 156/400 - Recompensa: 1708.0 - ε=0.100
# Episodio 157/400 - Recompensa: 2892.0 - ε=0.100
# Episodio 158/400 - Recompensa: 2416.0 - ε=0.100
# Episodio 159/400 - Recompensa: 1886.0 - ε=0.100
# Episodio 160/400 - Recompensa: 2136.0 - ε=0.100
# Episodio 161/400 - Recompensa: 2679.0 - ε=0.100
# Episodio 162/400 - Recompensa: 1173.0 - ε=0.100
# Episodio 163/400 - Recompensa: 2738.0 - ε=0.100
# Episodio 164/400 - Recompensa: 1436.0 - ε=0.100
# Episodio 165/400 - Recompensa: 2119.0 - ε=0.100
# Episodio 166/400 - Recompensa: 1901.0 - ε=0.100
# Episodio 167/400 - Recompensa: 1660.0 - ε=0.100
# Episodio 168/400 - Recompensa: 2569.0 - ε=0.100
# Episodio 169/400 - Recompensa: 2998.0 - ε=0.100
# Episodio 170/400 - Recompensa: 1890.0 - ε=0.100
# Episodio 171/400 - Recompensa: 1666.0 - ε=0.100
# Episodio 172/400 - Recompensa: 1652.0 - ε=0.100
# Episodio 173/400 - Recompensa: 608.0 - ε=0.100
# Episodio 174/400 - Recompensa: 1930.0 - ε=0.100
# Episodio 175/400 - Recompensa: 3177.0 - ε=0.100
# Episodio 176/400 - Recompensa: 1053.0 - ε=0.100
# Episodio 177/400 - Recompensa: 2183.0 - ε=0.100
# Episodio 178/400 - Recompensa: 2017.0 - ε=0.100
# Episodio 179/400 - Recompensa: 2185.0 - ε=0.100
# Episodio 180/400 - Recompensa: 1451.0 - ε=0.100
# Episodio 181/400 - Recompensa: 1700.0 - ε=0.100
# Episodio 182/400 - Recompensa: 2596.0 - ε=0.100
# Episodio 183/400 - Recompensa: 1530.0 - ε=0.100
# Episodio 184/400 - Recompensa: 1560.0 - ε=0.100
# Episodio 185/400 - Recompensa: 1547.0 - ε=0.100
# Episodio 186/400 - Recompensa: 2521.0 - ε=0.100
# Episodio 187/400 - Recompensa: 2039.0 - ε=0.100
# Episodio 188/400 - Recompensa: 2158.0 - ε=0.100
# Episodio 189/400 - Recompensa: 1483.0 - ε=0.100
# Episodio 190/400 - Recompensa: 1775.0 - ε=0.100
# Episodio 191/400 - Recompensa: 432.0 - ε=0.100
# Episodio 192/400 - Recompensa: 2100.0 - ε=0.100
# Episodio 193/400 - Recompensa: 1403.0 - ε=0.100
# Episodio 194/400 - Recompensa: 1885.0 - ε=0.100
# Episodio 195/400 - Recompensa: 2031.0 - ε=0.100
# Episodio 196/400 - Recompensa: 1100.0 - ε=0.100
# Episodio 197/400 - Recompensa: 1130.0 - ε=0.100
# Episodio 198/400 - Recompensa: 432.0 - ε=0.100
# Episodio 199/400 - Recompensa: 2548.0 - ε=0.100
# Episodio 200/400 - Recompensa: 1923.0 - ε=0.100
# Episodio 201/400 - Recompensa: 1000.0 - ε=0.100
# Episodio 202/400 - Recompensa: 1682.0 - ε=0.100
# Episodio 203/400 - Recompensa: 1458.0 - ε=0.100
# Episodio 204/400 - Recompensa: 1611.0 - ε=0.100
# Episodio 205/400 - Recompensa: 2318.0 - ε=0.100
# Episodio 206/400 - Recompensa: 2584.0 - ε=0.100
# Episodio 207/400 - Recompensa: 2560.0 - ε=0.100
# Episodio 208/400 - Recompensa: 1393.0 - ε=0.100
# Episodio 209/400 - Recompensa: 1953.0 - ε=0.100
# Episodio 210/400 - Recompensa: 2354.0 - ε=0.100
# Episodio 211/400 - Recompensa: 1475.0 - ε=0.100
# Episodio 212/400 - Recompensa: 1359.0 - ε=0.100
# Episodio 213/400 - Recompensa: 1021.0 - ε=0.100
# Episodio 214/400 - Recompensa: 1744.0 - ε=0.100
# Episodio 215/400 - Recompensa: 2162.0 - ε=0.100
# Episodio 216/400 - Recompensa: 1733.0 - ε=0.100
# Episodio 217/400 - Recompensa: 1895.0 - ε=0.100
# Episodio 218/400 - Recompensa: 1094.0 - ε=0.100
# Episodio 219/400 - Recompensa: 1652.0 - ε=0.100
# Episodio 220/400 - Recompensa: 1276.0 - ε=0.100
# Episodio 221/400 - Recompensa: 432.0 - ε=0.100
# Episodio 222/400 - Recompensa: 1499.0 - ε=0.100
# Episodio 223/400 - Recompensa: 609.0 - ε=0.100
# Episodio 224/400 - Recompensa: 1233.0 - ε=0.100
# Episodio 225/400 - Recompensa: 1472.0 - ε=0.100
# Episodio 226/400 - Recompensa: 2092.0 - ε=0.100
# Episodio 227/400 - Recompensa: 1127.0 - ε=0.100
# Episodio 228/400 - Recompensa: 1937.0 - ε=0.100
# Episodio 229/400 - Recompensa: 1777.0 - ε=0.100
# Episodio 230/400 - Recompensa: 1054.0 - ε=0.100
# Episodio 231/400 - Recompensa: 1791.0 - ε=0.100
# Episodio 232/400 - Recompensa: 1816.0 - ε=0.100
# Episodio 233/400 - Recompensa: 1767.0 - ε=0.100
# Episodio 234/400 - Recompensa: 1325.0 - ε=0.100
# Episodio 235/400 - Recompensa: 2236.0 - ε=0.100
# Episodio 236/400 - Recompensa: 1736.0 - ε=0.100
# Episodio 237/400 - Recompensa: 1780.0 - ε=0.100
# Episodio 238/400 - Recompensa: 1859.0 - ε=0.100
# Episodio 239/400 - Recompensa: 1476.0 - ε=0.100
# Episodio 240/400 - Recompensa: 1422.0 - ε=0.100
# Episodio 241/400 - Recompensa: 1222.0 - ε=0.100
# Episodio 242/400 - Recompensa: 1526.0 - ε=0.100
# Episodio 243/400 - Recompensa: 1466.0 - ε=0.100
# Episodio 244/400 - Recompensa: 2275.0 - ε=0.100
# Episodio 245/400 - Recompensa: 1861.0 - ε=0.100
# Episodio 246/400 - Recompensa: 905.0 - ε=0.100
# Episodio 247/400 - Recompensa: 1071.0 - ε=0.100
# Episodio 248/400 - Recompensa: 3560.0 - ε=0.100
# Episodio 249/400 - Recompensa: 1189.0 - ε=0.100
# Episodio 250/400 - Recompensa: 1011.0 - ε=0.100
# Episodio 251/400 - Recompensa: 1635.0 - ε=0.100
# Episodio 252/400 - Recompensa: 1649.0 - ε=0.100
# Episodio 253/400 - Recompensa: 1456.0 - ε=0.100
# Episodio 254/400 - Recompensa: 2384.0 - ε=0.100
# Episodio 255/400 - Recompensa: 2994.0 - ε=0.100
# Episodio 256/400 - Recompensa: 1571.0 - ε=0.100
# Episodio 257/400 - Recompensa: 1749.0 - ε=0.100
# Episodio 258/400 - Recompensa: 1970.0 - ε=0.100
# Episodio 259/400 - Recompensa: 1263.0 - ε=0.100
# Episodio 260/400 - Recompensa: 2126.0 - ε=0.100
# Episodio 261/400 - Recompensa: 1576.0 - ε=0.100
# Episodio 262/400 - Recompensa: 2127.0 - ε=0.100
# Episodio 263/400 - Recompensa: 2051.0 - ε=0.100
# Episodio 264/400 - Recompensa: 1208.0 - ε=0.100
# Episodio 265/400 - Recompensa: 1934.0 - ε=0.100
# Episodio 266/400 - Recompensa: 608.0 - ε=0.100
# Episodio 267/400 - Recompensa: 1338.0 - ε=0.100
# Episodio 268/400 - Recompensa: 674.0 - ε=0.100
# Episodio 269/400 - Recompensa: 432.0 - ε=0.100
# Episodio 270/400 - Recompensa: 1416.0 - ε=0.100
# Episodio 271/400 - Recompensa: 2565.0 - ε=0.100
# Episodio 272/400 - Recompensa: 1444.0 - ε=0.100
# Episodio 273/400 - Recompensa: 1107.0 - ε=0.100
# Episodio 274/400 - Recompensa: 1647.0 - ε=0.100
# Episodio 275/400 - Recompensa: 1408.0 - ε=0.100
# Episodio 276/400 - Recompensa: 1741.0 - ε=0.100
# Episodio 277/400 - Recompensa: 1406.0 - ε=0.100
# Episodio 278/400 - Recompensa: 2002.0 - ε=0.100
# Episodio 279/400 - Recompensa: 1045.0 - ε=0.100
# Episodio 280/400 - Recompensa: 2065.0 - ε=0.100
# Episodio 281/400 - Recompensa: 682.0 - ε=0.100
# Episodio 282/400 - Recompensa: 2154.0 - ε=0.100
# Episodio 283/400 - Recompensa: 432.0 - ε=0.100
# Episodio 284/400 - Recompensa: 1499.0 - ε=0.100
# Episodio 285/400 - Recompensa: 709.0 - ε=0.100
# Episodio 286/400 - Recompensa: 1335.0 - ε=0.100
# Episodio 287/400 - Recompensa: 2106.0 - ε=0.100
# Episodio 288/400 - Recompensa: 1148.0 - ε=0.100
# Episodio 289/400 - Recompensa: 1275.0 - ε=0.100
# Episodio 290/400 - Recompensa: 1148.0 - ε=0.100
# Episodio 291/400 - Recompensa: 1177.0 - ε=0.100
# Episodio 292/400 - Recompensa: 1738.0 - ε=0.100
# Episodio 293/400 - Recompensa: 1089.0 - ε=0.100
# Episodio 294/400 - Recompensa: 1645.0 - ε=0.100
# Episodio 295/400 - Recompensa: 608.0 - ε=0.100
# Episodio 296/400 - Recompensa: 1452.0 - ε=0.100
# Episodio 297/400 - Recompensa: 1635.0 - ε=0.100
# Episodio 298/400 - Recompensa: 2055.0 - ε=0.100
# Episodio 299/400 - Recompensa: 1748.0 - ε=0.100
# Episodio 300/400 - Recompensa: 1062.0 - ε=0.100
# Episodio 301/400 - Recompensa: 1827.0 - ε=0.100
# Episodio 302/400 - Recompensa: 1135.0 - ε=0.100
# Episodio 303/400 - Recompensa: 2230.0 - ε=0.100
# Episodio 304/400 - Recompensa: 1541.0 - ε=0.100
# Episodio 305/400 - Recompensa: 1213.0 - ε=0.100
# Episodio 306/400 - Recompensa: 1796.0 - ε=0.100
# Episodio 307/400 - Recompensa: 1851.0 - ε=0.100
# Episodio 308/400 - Recompensa: 1106.0 - ε=0.100
# Episodio 309/400 - Recompensa: 713.0 - ε=0.100
# Episodio 310/400 - Recompensa: 2294.0 - ε=0.100
# Episodio 311/400 - Recompensa: 1448.0 - ε=0.100
# Episodio 312/400 - Recompensa: 358.0 - ε=0.100
# Episodio 313/400 - Recompensa: 432.0 - ε=0.100
# Episodio 314/400 - Recompensa: 2019.0 - ε=0.100
# Episodio 315/400 - Recompensa: 1069.0 - ε=0.100
# Episodio 316/400 - Recompensa: 1952.0 - ε=0.100
# Episodio 317/400 - Recompensa: 2149.0 - ε=0.100
# Episodio 318/400 - Recompensa: 2502.0 - ε=0.100
# Episodio 319/400 - Recompensa: 1094.0 - ε=0.100
# Episodio 320/400 - Recompensa: 608.0 - ε=0.100
# Episodio 321/400 - Recompensa: 1469.0 - ε=0.100
# Episodio 322/400 - Recompensa: 683.0 - ε=0.100
# Episodio 323/400 - Recompensa: 1672.0 - ε=0.100
# Episodio 324/400 - Recompensa: 1512.0 - ε=0.100
# Episodio 325/400 - Recompensa: 1483.0 - ε=0.100
# Episodio 326/400 - Recompensa: 1333.0 - ε=0.100
# Episodio 327/400 - Recompensa: 1958.0 - ε=0.100
# Episodio 328/400 - Recompensa: 2110.0 - ε=0.100
# Episodio 329/400 - Recompensa: 685.0 - ε=0.100
# Episodio 330/400 - Recompensa: 2203.0 - ε=0.100
# Episodio 331/400 - Recompensa: 1078.0 - ε=0.100
# Episodio 332/400 - Recompensa: 2260.0 - ε=0.100
# Episodio 333/400 - Recompensa: 2249.0 - ε=0.100
# Episodio 334/400 - Recompensa: 2149.0 - ε=0.100
# Episodio 335/400 - Recompensa: 1426.0 - ε=0.100
# Episodio 336/400 - Recompensa: 1615.0 - ε=0.100
# Episodio 337/400 - Recompensa: 1235.0 - ε=0.100
# Episodio 338/400 - Recompensa: 1504.0 - ε=0.100
# Episodio 339/400 - Recompensa: 1876.0 - ε=0.100
# Episodio 340/400 - Recompensa: 1943.0 - ε=0.100
# Episodio 341/400 - Recompensa: 1044.0 - ε=0.100
# Episodio 342/400 - Recompensa: 1586.0 - ε=0.100
# Episodio 343/400 - Recompensa: 1591.0 - ε=0.100
# Episodio 344/400 - Recompensa: 2381.0 - ε=0.100
# Episodio 345/400 - Recompensa: 1590.0 - ε=0.100
# Episodio 346/400 - Recompensa: 1429.0 - ε=0.100
# Episodio 347/400 - Recompensa: 1645.0 - ε=0.100
# Episodio 348/400 - Recompensa: 1955.0 - ε=0.100
# Episodio 349/400 - Recompensa: 1582.0 - ε=0.100
# Episodio 350/400 - Recompensa: 2715.0 - ε=0.100
# Episodio 351/400 - Recompensa: 1590.0 - ε=0.100
# Episodio 352/400 - Recompensa: 593.0 - ε=0.100
# Episodio 353/400 - Recompensa: 1148.0 - ε=0.100
# Episodio 354/400 - Recompensa: 1595.0 - ε=0.100
# Episodio 355/400 - Recompensa: 2198.0 - ε=0.100
# Episodio 356/400 - Recompensa: 2238.0 - ε=0.100
# Episodio 357/400 - Recompensa: 1401.0 - ε=0.100
# Episodio 358/400 - Recompensa: 851.0 - ε=0.100
# Episodio 359/400 - Recompensa: 2020.0 - ε=0.100
# Episodio 360/400 - Recompensa: 1773.0 - ε=0.100
# Episodio 361/400 - Recompensa: 1207.0 - ε=0.100
# Episodio 362/400 - Recompensa: 1968.0 - ε=0.100
# Episodio 363/400 - Recompensa: 1522.0 - ε=0.100
# Episodio 364/400 - Recompensa: 1931.0 - ε=0.100
# Episodio 365/400 - Recompensa: 1371.0 - ε=0.100
# Episodio 366/400 - Recompensa: 2253.0 - ε=0.100
# Episodio 367/400 - Recompensa: 1612.0 - ε=0.100
# Episodio 368/400 - Recompensa: 2257.0 - ε=0.100
# Episodio 369/400 - Recompensa: 2026.0 - ε=0.100
# Episodio 370/400 - Recompensa: 2845.0 - ε=0.100
# Episodio 371/400 - Recompensa: 1947.0 - ε=0.100
# Episodio 372/400 - Recompensa: 1462.0 - ε=0.100
# Episodio 373/400 - Recompensa: 1863.0 - ε=0.100
# Episodio 374/400 - Recompensa: 1467.0 - ε=0.100
# Episodio 375/400 - Recompensa: 1485.0 - ε=0.100
# Episodio 376/400 - Recompensa: 432.0 - ε=0.100
# Episodio 377/400 - Recompensa: 2125.0 - ε=0.100
# Episodio 378/400 - Recompensa: 1960.0 - ε=0.100
# Episodio 379/400 - Recompensa: 2511.0 - ε=0.100
# Episodio 380/400 - Recompensa: 608.0 - ε=0.100
# Episodio 381/400 - Recompensa: 1553.0 - ε=0.100
# Episodio 382/400 - Recompensa: 1700.0 - ε=0.100
# Episodio 383/400 - Recompensa: 1936.0 - ε=0.100
# Episodio 384/400 - Recompensa: 1440.0 - ε=0.100
# Episodio 385/400 - Recompensa: 2689.0 - ε=0.100
# Episodio 386/400 - Recompensa: 1992.0 - ε=0.100
# Episodio 387/400 - Recompensa: 1859.0 - ε=0.100
# Episodio 388/400 - Recompensa: 1891.0 - ε=0.100
# Episodio 389/400 - Recompensa: 1586.0 - ε=0.100
# Episodio 390/400 - Recompensa: 842.0 - ε=0.100
# Episodio 391/400 - Recompensa: 1646.0 - ε=0.100
# Episodio 392/400 - Recompensa: 1454.0 - ε=0.100
# Episodio 393/400 - Recompensa: 2127.0 - ε=0.100
# Episodio 394/400 - Recompensa: 1786.0 - ε=0.100
# Episodio 395/400 - Recompensa: 2301.0 - ε=0.100
# Episodio 396/400 - Recompensa: 1940.0 - ε=0.100
# Episodio 397/400 - Recompensa: 711.0 - ε=0.100
# Episodio 398/400 - Recompensa: 1596.0 - ε=0.100
# Episodio 399/400 - Recompensa: 1215.0 - ε=0.100
# Episodio 400/400 - Recompensa: 1906.0 - ε=0.100

# %%
# Crear un nuevo entorno para reproducción
video_env = gym_super_mario_bros.make("SuperMarioBros-v0")
video_env = JoypadSpace(video_env, SIMPLE_MOVEMENT)

frames = []
obs = video_env.reset()
state = preprocess_frame(obs)
state_stack = np.stack([state]*4, axis=0)

done = False
while not done:
    with torch.no_grad():
        state_tensor = torch.tensor(state_stack, dtype=torch.float32, device=device).unsqueeze(0)
        action = policy_net(state_tensor).argmax().item()  # siempre la mejor acción
    next_obs, reward, done, info = video_env.step(action)
    frame = video_env.render(mode='rgb_array')
    frames.append(frame)
    
    next_frame = preprocess_frame(next_obs)
    state_stack = np.concatenate([state_stack[1:], next_frame[np.newaxis, ...]], axis=0)

video_env.close()

# Guardar video con OpenCV
height, width, layers = frames[0].shape
video_name = 'mario_final.mp4'
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
video = cv2.VideoWriter(video_name, fourcc, 30, (width, height))

for f in frames:
    # Convertir RGB a BGR para OpenCV
    video.write(cv2.cvtColor(f, cv2.COLOR_RGB2BGR))
video.release()
print("Video guardado como", video_name)
# Out:
# /usr/local/lib/python3.11/dist-packages/gym/envs/registration.py:593: UserWarning: WARN: The environment SuperMarioBros-v0 is out of date. You should consider upgrading to version `v3`.
#   logger.warn(
# /usr/local/lib/python3.11/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.11/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.11/dist-packages/gym/core.py:43: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# /usr/local/lib/python3.11/dist-packages/gym/utils/passive_env_checker.py:280: UserWarning: WARN: No render modes was declared in the environment (env.metadata['render_modes'] is None or not defined), you may have trouble when calling `.render()`.
#   logger.warn(
# Video guardado como mario_final.mp4

# %%
import imageio
from IPython.display import HTML
from base64 import b64encode

# Crear entorno limpio SOLO para grabar video
video_env = gym_super_mario_bros.make("SuperMarioBros-v0")
video_env = JoypadSpace(video_env, SIMPLE_MOVEMENT)

frames = []
obs = video_env.reset()
state = preprocess_frame(obs)
state_stack = np.stack([state]*4, axis=0)

done = False
while not done:
    with torch.no_grad():
        state_tensor = torch.tensor(state_stack, dtype=torch.float32, device=device).unsqueeze(0)
        action = policy_net(state_tensor).argmax().item()
    
    next_obs, reward, done, info = video_env.step(action)

    # ⚠️ Captura directa desde la pantalla del entorno
    if hasattr(video_env.unwrapped, "screen"):
        frame = video_env.unwrapped.screen.copy()
        frames.append(frame)

    next_frame = preprocess_frame(next_obs)
    state_stack = np.concatenate([state_stack[1:], next_frame[np.newaxis, ...]], axis=0)

video_env.close()

# Guardar video
video_name = "mario_final.mp4"
imageio.mimsave(video_name, frames, fps=30)
print("✅ Video guardado como:", video_name)

# Mostrar el video directamente
def display_video(filename):
    with open(filename, "rb") as f:
        video_data = f.read()
    data_url = "data:video/mp4;base64," + b64encode(video_data).decode()
    return HTML(f"""
        <video width="640" height="480" controls autoplay loop>
            <source src="{data_url}" type="video/mp4">
        </video>
    """)

display_video(video_name)
# Out:
# ✅ Video guardado como: mario_final.mp4
#         <video width="640" height="480" controls autoplay loop>
#             <source src="data:video/mp4;base64,..." type="video/mp4">
#         </video>
